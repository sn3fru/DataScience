# %%
# %cd /content
# !git clone https://github.com/rakuri255/UltraSinger.git
# %cd /content/UltraSinger
# !pip install --no-cache-dir -r requirements-linux.txt
# !pip install --no-cache-dir torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install --no-cache-dir tensorflow[and-cuda]==2.17.1
# %cd /content/UltraSinger/src
# Out:
# /content
# fatal: destination path 'UltraSinger' already exists and is not an empty directory.
# /content/UltraSinger
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 21.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 261.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 215.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 341.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 341.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 196.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content
# 1. Clona o repositório (se já existir, ele avisa e segue)
# !git clone https://github.com/rakuri255/UltraSinger.git

# %cd /content/UltraSinger

# 2. Instalação ROBUSTA de dependências (Adicionei o que costuma faltar)
# Instala o requirements principal E o do linux para garantir
# !pip install --no-cache-dir -r requirements.txt
# !pip install --no-cache-dir -r requirements-linux.txt

# 3. Instalação manual das bibliotecas de IA (Torch/Tensorflow)
# !pip install --no-cache-dir torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install --no-cache-dir tensorflow[and-cuda]==2.17.1

# 4. A CORREÇÃO DO SEU ERRO (Instala explicitamente o Levenshtein e outros úteis)
# !pip install Levenshtein yt-dlp ffmpeg-python

# %cd /content/UltraSinger/src

# 5. Roda o UltraSinger
# !python UltraSinger.py -i https://www.youtube.com/watch?v=YwNs1Z0qRY0 -o /content/output

# %%
# 1. Cria o arquivo de requisitos
requirements_txt = """
absl-py==2.3.0
aiohappyeyeballs==2.6.1
aiohttp==3.12.9
aiosignal==1.3.2
alembic==1.16.1
antlr4-python3-runtime==4.9.3
appdirs==1.4.4
asteroid-filterbanks==0.4.0
astroid==3.3.10
astunparse==1.6.3
async-timeout==5.0.1
attrs==25.3.0
audioread==3.0.1
av==14.4.0
black==25.1.0
cachetools==5.5.2
certifi==2025.4.26
cffi==1.17.1
chardet==5.2.0
charset-normalizer==3.4.2
click==8.2.1
cloudpickle==3.1.1
colorama==0.4.6
coloredlogs==15.0.1
colorlog==6.9.0
contourpy==1.3.2
crepe==0.0.16
ctranslate2==4.4.0
cycler==0.12.1
dataclasses==0.6
dataclasses-json==0.6.7
decorator==5.2.1
demucs==4.0.1
dill==0.4.0
docopt==0.6.2
dora-search==0.1.12
einops==0.8.1
exceptiongroup==1.3.0
faster-whisper==1.1.0
ffmpeg-python==0.2.0
filelock==3.18.0
flatbuffers==25.2.10
fonttools==4.58.1
frozenlist==1.6.2
fsspec[http]==2025.5.1
future==1.0.0
gast==0.4.0
google-auth==2.40.3
google-auth-oauthlib==0.4.6
google-pasta==0.2.0
greenlet==3.2.3
grpcio==1.72.1
h5py==3.13.0
hmmlearn==0.3.3
huggingface-hub==0.32.4
humanfriendly==10.0
hyperpyyaml==1.2.2
idna==3.10
imageio==2.37.0
iniconfig==2.1.0
inputimeout==1.0.4
isort==6.0.1
jinja2==3.1.6
joblib==1.5.1
jsonpickle==4.1.1
julius==0.2.7
keras==2.10.0
keras-preprocessing==1.1.2
kiwisolver==1.4.8
lameenc==1.8.1
langcodes==3.5.0
language-data==1.3.0
levenshtein==0.27.1
libclang==18.1.1
librosa==0.9.2
lightning==2.5.1.post0
lightning-utilities==0.14.3
llvmlite==0.44.0
mako==1.3.10
marisa-trie==1.2.1
markdown==3.8
markdown-it-py==3.0.0
markupsafe==3.0.2
marshmallow==3.26.1
matplotlib==3.10.3
mccabe==0.7.0
mdurl==0.1.2
mido==1.3.3
more-itertools==10.7.0
mpmath==1.3.0
multidict==6.4.4
music21==9.7.0
musicbrainzngs==0.7.1
mypy-extensions==1.1.0
networkx==3.4.2
nltk==3.9.1
num2words==0.5.14
numba==0.61.2
numpy==1.26.4
oauthlib==3.2.2
omegaconf==2.3.0
onnxruntime==1.22.0
openunmix==1.3.0
opt-einsum==3.4.0
optuna==4.3.0
packaging==24.2
pandas==2.3.0
pathspec==0.12.1
pillow==11.2.1
platformdirs==4.3.8
pluggy==1.6.0
pooch==1.8.2
pretty-midi==0.2.10
primepy==1.3
propcache==0.3.1
protobuf==3.19.6
pyannote-audio==3.3.2
pyannote-core==5.0.0
pyannote-database==5.1.3
pyannote-metrics==3.2.1
pyannote-pipeline==3.0.1
pyasn1==0.6.1
pyasn1-modules==0.4.2
pycparser==2.22
pydub==0.25.1
pygments==2.19.1
pyhyphen==4.0.4
pylint==3.3.7
pyparsing==3.2.3
pyreadline3==3.5.4
pytest==8.4.0
python-dateutil==2.9.0.post0
python-levenshtein==0.27.1
pytorch-lightning==2.5.1.post0
pytorch-metric-learning==2.8.1
pytz==2025.2
pyyaml==6.0.2
rapidfuzz==3.13.0
regex==2024.11.6
requests==2.32.3
requests-oauthlib==2.0.0
resampy==0.4.3
retrying==1.3.4
rich==14.0.0
rsa==4.9.1
ruamel-yaml==0.18.12
ruamel-yaml-clib==0.2.12
safetensors==0.5.3
scikit-learn==1.6.1
scipy==1.15.3
semver==3.0.4
sentencepiece==0.2.0
shellingham==1.5.4
six==1.17.0
sortedcontainers==2.4.0
soundfile==0.13.1
speechbrain==1.0.3
sqlalchemy==2.0.41
submitit==1.5.3
sympy==1.14.0
tabulate==0.9.0
tensorboard==2.10.1
tensorboard-data-server==0.6.1
tensorboard-plugin-wit==1.8.1
tensorboardx==2.6
tensorflow==2.10.0
tensorflow-estimator==2.10.0
tensorflow-io-gcs-filesystem==0.31.0
termcolor==3.1.0
threadpoolctl==3.6.0
tokenizers==0.21.1
tomli==2.2.1
tomlkit==0.13.3
torch==2.5.1
torch-audiomentations==0.12.0
torch-pitch-shift==1.2.5
torchaudio==2.5.1
torchmetrics==1.7.2
tqdm==4.67.1
transformers==4.52.4
treetable==0.2.5
typer==0.16.0
typing-extensions==4.14.0
typing-inspect==0.9.0
tzdata==2025.2
unidecode==1.4.0
urllib3==2.4.0
webcolors==24.11.1
werkzeug==3.1.3
wheel==0.45.1
whisperx==3.3.1
wrapt==1.17.2
yarl==1.20.0
yt-dlp==2025.5.22
"""

# Salva o arquivo no disco do Colab
with open("requirements_custom.txt", "w") as f:
    f.write(requirements_txt)

print("📝 Arquivo requirements_custom.txt criado.")
print("⏳ Iniciando instalação... (Isso vai demorar uns minutos)")

# 2. Executa o PIP
# Adicionei flags para ignorar erros leves e tentar resolver dependências
# !pip install -r requirements_custom.txt --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# 📝 Arquivo requirements_custom.txt criado.
# ⏳ Iniciando instalação... (Isso vai demorar uns minutos)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 9.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# !pip install demucs
# Out:
# ...
#   Using cached demucs-4.0.1.tar.gz (1.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached dora_search-0.1.12.tar.gz (87 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached julius-0.2.7.tar.gz (59 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached lameenc-1.8.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (9.9 kB)
# ...
#   Using cached openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached submitit-1.5.3-py3-none-any.whl.metadata (7.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 134.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 107.1 MB/s eta 0:00:00
# ...

# %%
# !pip install whisperx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.6 MB/s eta 0:00:00
# ...
#   Using cached asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.0 MB/s eta 0:00:00
# ...
#   Using cached pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached pyannote.database-5.1.3-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached pyannote.pipeline-3.0.1-py3-none-any.whl.metadata (897 bytes)
# ...
#   Using cached semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# ...

# %%
# !pip install num2words
# Out:
# ...
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# 1. Limpa instalações conflitantes e força o NumPy 1.x
# !pip uninstall -y numpy
# !pip install "numpy<2.0"

# 2. Clona e prepara o ambiente
# %cd /content
# !git clone https://github.com/rakuri255/UltraSinger.git
# %cd /content/UltraSinger

# 3. Instala dependências (Forçando compatibilidade)
# O segredo é instalar o tensorflow e torch DEPOIS do numpy antigo
# !pip install --no-cache-dir -r requirements.txt
# !pip install --no-cache-dir torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install --no-cache-dir tensorflow[and-cuda]==2.17.1

# 4. Instala as libs que costumam faltar (garantia)
# !pip install Levenshtein yt-dlp ffmpeg-python dataclasses-json packaging termcolor

# 5. Roda o script
# %cd /content/UltraSinger/src
# !python UltraSinger.py -i https://www.youtube.com/watch?v=YwNs1Z0qRY0 -o /content/output
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 118.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# whisperx 3.7.4 requires numpy<2.1.0,>=2.0.2; python_version < "3.13", but you have numpy 1.26.4 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 2.8.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !python UltraSinger.py -i https://www.youtube.com/watch?v=YwNs1Z0qRY0 -o /content/output
